# %%
allconcepts = ""

# %%
#allconcepts is a list (with length equal to the number of concepts) in which each row contains a list with the following structure: [concept, WS, AS_I, AS_II, Tests]
#WS, AS_I, AS_II and Tests are list with tuples input-output

numBatches = 3
numTests = 5

queries = [[]]*len(allconcepts)
test_targets = [[]]*len(allconcepts)
common_prompts = [[]]*len(allconcepts)

for c in range(0, len(allconcepts)):
  queries[c] = [[]]*numBatches
  test_targets[c] = [[]]*numBatches
  common_prompts[c] = [""]*numBatches
  for b in range(0, numBatches):
    queries[c][b] = [""]*numTests
    test_targets[c][b] = [""]*numTests
    
    if b == 0:
      for e in range(0, len(allconcepts[i][1])):
        common_prompts[c][b] = common_prompts[c][b] + "Input: "
        if allconcepts[c][1][e][0] == '':
          common_prompts[c][b] = common_prompts[c][b] + "-\n"
        else:
          common_prompts[c][b] = common_prompts[c][b] + allconcepts[c][1][e][0] +"\n"

        common_prompts[c][b] = common_prompts[c][b] + "Output: "
        if allconcepts[c][1][e][1] == '':
          common_prompts[c][b] = common_prompts[c][b] + "-\n\n"
        else:
          common_prompts[c][b] = common_prompts[c][b] + allconcepts[c][1][e][1] +"\n\n"

    if b == 1:
      common_prompts[c][b] = common_prompts[c][0]
      for e in range(0, len(allconcepts[i][2])):
        common_prompts[c][b] = common_prompts[c][b] + "Input: "
        if allconcepts[c][2][e][0] == '':
          common_prompts[c][b] = common_prompts[c][b] + "-\n"
        else:
          common_prompts[c][b] = common_prompts[c][b] + allconcepts[c][2][e][0] +"\n"

        common_prompts[c][b] = common_prompts[c][b] + "Output: "
        if allconcepts[c][2][e][1] == '':
          common_prompts[c][b] = common_prompts[c][b] + "-\n\n"
        else:
          common_prompts[c][b] = common_prompts[c][b] + allconcepts[c][2][e][1] +"\n\n"

    if b == 2:
      common_prompts[c][b] = common_prompts[c][1]
      for e in range(0, len(allconcepts[i][3])):
        common_prompts[c][b] = common_prompts[c][b] + "Input: "
        if allconcepts[c][3][e][0] == '':
          common_prompts[c][b] = common_prompts[c][b] + "-\n"
        else:
          common_prompts[c][b] = common_prompts[c][b] + allconcepts[c][3][e][0] +"\n"

        common_prompts[c][b] = common_prompts[c][b] + "Output: "
        if allconcepts[c][3][e][1] == '':
          common_prompts[c][b] = common_prompts[c][b] + "-\n\n"
        else:
          common_prompts[c][b] = common_prompts[c][b] + allconcepts[c][3][e][1] +"\n\n"


    for t in range(0, numTest):
      queries[c][b][t] = common_prompts[c][b]
      queries[c][b][t] = queries[c][b][t] + "Input: "
      if allconcepts[c][4][t][0] == '':
        queries[c][b][t] = queries[c][b][t] + "-\nOutput:"
      else:
        queries[c][b][t] = queries[c][b][t] + allconcepts[c][4][t][0] +"\nOutput:"

      if allconcepts[c][4][t][1] == '':
        test_targets[c][b][t] = "-"
      else:
        test_targets[c][b][t] = allconcepts[c][4][t][1]
